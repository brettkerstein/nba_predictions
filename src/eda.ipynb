# %%
import pandas as pd
import numpy as np
import nba_api

# %%
import logging
from nba_api.stats.static import players
from nba_api.stats.endpoints import playercareerstats
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from flask import Flask, render_template_string
import plotly.express as px
import plotly.io as pio

# Set up logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

def get_player_stats(player_id, season='2023-24'):
    try:
        career = playercareerstats.PlayerCareerStats(player_id=player_id)
        df = career.get_data_frames()[0]
        return df[df['SEASON_ID'] == season].iloc[0]
    except Exception as e:
        logging.error(f"Error getting stats for player {player_id}: {str(e)}")
        return None

def prepare_data():
    active_players = [player for player in players.get_active_players()]
    data = []
    for player in active_players[:50]:  # Limit to 50 players for this example
        try:
            stats = get_player_stats(player['id'])
            if stats is not None:
                data.append({
                    'PLAYER_ID': stats['PLAYER_ID'],
                    'PLAYER_NAME': player['full_name'],
                    'PTS': stats['PTS'],
                    'AST': stats['AST'],
                    'REB': stats['REB'],
                    'STL': stats['STL'],
                    'BLK': stats['BLK']
                })
        except Exception as e:
            logging.error(f"Error processing player {player['full_name']}: {str(e)}")
    return pd.DataFrame(data)

def cluster_players(df, n_clusters=5):
    features = ['PTS', 'AST', 'REB', 'STL', 'BLK']
    X = df[features]
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    df['Cluster'] = kmeans.fit_predict(X_scaled)
    return df

# Main execution
if __name__ == "__main__":
    df = prepare_data()
    clustered_df = cluster_players(df)
    print(clustered_df.head())
# Out:
# 2024-09-24 21:20:13,626 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:14,225 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630173 HTTP/11" 200 1439
# 2024-09-24 21:20:14,265 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:14,584 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628389 HTTP/11" 200 1934
# 2024-09-24 21:20:14,650 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:15,145 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630534 HTTP/11" 200 1190
# 2024-09-24 21:20:15,198 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:15,386 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630583 HTTP/11" 200 1145
# 2024-09-24 21:20:15,415 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:15,904 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1629638 HTTP/11" 200 1735
# 2024-09-24 21:20:15,919 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:16,138 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628960 HTTP/11" 200 1872
# 2024-09-24 21:20:16,170 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:16,475 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628386 HTTP/11" 200 1800
# 2024-09-24 21:20:16,517 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:16,987 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1641851 HTTP/11" 200 616
# 2024-09-24 21:20:17,015 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:17,450 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630631 HTTP/11" 200 1366
# 2024-09-24 21:20:17,492 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:17,669 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=203937 HTTP/11" 200 2288
# 2024-09-24 21:20:17,710 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:17,889 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=203507 HTTP/11" 200 2528
# 2024-09-24 21:20:17,920 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:18,319 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=203648 HTTP/11" 200 1384
# 2024-09-24 21:20:18,356 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:18,727 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630175 HTTP/11" 200 1172
# 2024-09-24 21:20:18,768 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:19,158 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628384 HTTP/11" 200 1863
# 2024-09-24 21:20:19,201 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:19,463 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1627853 HTTP/11" 200 1300
# 2024-09-24 21:20:19,533 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:19,791 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630166 HTTP/11" 200 1187
# 2024-09-24 21:20:19,820 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:20,061 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1629028 HTTP/11" 200 1552
# 2024-09-24 21:20:20,092 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:20,325 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628962 HTTP/11" 200 1277
# 2024-09-24 21:20:20,354 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:20,546 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630641 HTTP/11" 200 620
# 2024-09-24 21:20:20,563 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:20,768 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628963 HTTP/11" 200 1470
# 2024-09-24 21:20:20,803 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:21,004 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1641735 HTTP/11" 200 719
# 2024-09-24 21:20:21,027 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:21,454 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1631116 HTTP/11" 200 918
# 2024-09-24 21:20:21,502 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:21,800 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630163 HTTP/11" 200 1267
# 2024-09-24 21:20:21,842 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:22,737 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628964 HTTP/11" 200 1438
# 2024-09-24 21:20:22,773 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:23,021 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1631094 HTTP/11" 200 1015
# 2024-09-24 21:20:23,045 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:23,380 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630217 HTTP/11" 200 1570
# 2024-09-24 21:20:23,408 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:23,727 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630625 HTTP/11" 200 1072
# 2024-09-24 21:20:23,774 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:23,993 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1631230 HTTP/11" 200 765
# 2024-09-24 21:20:24,006 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:24,192 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=203084 HTTP/11" 200 2452
# 2024-09-24 21:20:24,206 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:24,392 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630567 HTTP/11" 200 1054
# 2024-09-24 21:20:24,417 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:24,832 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1629628 HTTP/11" 200 1479
# 2024-09-24 21:20:24,863 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:25,111 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1629646 HTTP/11" 200 1215
# 2024-09-24 21:20:25,155 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:25,380 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1641734 HTTP/11" 200 828
# 2024-09-24 21:20:25,404 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:25,594 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1628966 HTTP/11" 200 1724
# 2024-09-24 21:20:25,623 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:25,802 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=201587 HTTP/11" 200 2896
# 2024-09-24 21:20:25,823 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:26,307 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1629647 HTTP/11" 200 1317
# 2024-09-24 21:20:26,334 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:26,640 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=203078 HTTP/11" 200 2474
# 2024-09-24 21:20:26,667 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:26,876 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1627736 HTTP/11" 200 1992
# 2024-09-24 21:20:26,918 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:27,378 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630699 HTTP/11" 200 937
# 2024-09-24 21:20:27,409 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:27,643 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1631262 HTTP/11" 200 937
# 2024-09-24 21:20:27,667 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:28,013 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=202722 HTTP/11" 200 1936
# 2024-09-24 21:20:28,046 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:28,231 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=201976 HTTP/11" 200 2809
# 2024-09-24 21:20:28,267 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:28,445 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1630180 HTTP/11" 200 1378
# 2024-09-24 21:20:28,476 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:28,738 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1629048 HTTP/11" 200 1239
# 2024-09-24 21:20:28,762 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:29,481 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1641931 HTTP/11" 200 625
# 2024-09-24 21:20:29,515 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:29,825 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=202687 HTTP/11" 200 2247
# 2024-09-24 21:20:29,860 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:30,049 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1641710 HTTP/11" 200 805
# 2024-09-24 21:20:30,079 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:30,313 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1641778 HTTP/11" 200 984
# 2024-09-24 21:20:30,337 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:30,586 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=1631205 HTTP/11" 200 1036
# 2024-09-24 21:20:30,630 - DEBUG - Starting new HTTPS connection (1): stats.nba.com:443
# 2024-09-24 21:20:30,881 - DEBUG - https://stats.nba.com:443 "GET /stats/playercareerstats?LeagueID=&PerMode=Totals&PlayerID=203992 HTTP/11" 200 1586
#    PLAYER_ID               PLAYER_NAME   PTS  AST  REB  STL  BLK  Cluster
# 0    1630173          Precious Achiuwa   193   44  136   16   12        0
# 1    1628389               Bam Adebayo  1367  278  737   81   66        2
# 2    1630534              Ochai Agbaji   274   47  126   27   29        4
# 3    1630583              Santi Aldama   654  138  352   43   54        3
# 4    1629638  Nickeil Alexander-Walker   655  204  167   64   42        3
# c:\Users\brett\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
clustered_df[
# Out:
#    PLAYER_ID               PLAYER_NAME   PTS  AST  REB  STL  BLK  Cluster
# 0    1630173          Precious Achiuwa   193   44  136   16   12        0
# 1    1628389               Bam Adebayo  1367  278  737   81   66        2
# 2    1630534              Ochai Agbaji   274   47  126   27   29        4
# 3    1630583              Santi Aldama   654  138  352   43   54        3
# 4    1629638  Nickeil Alexander-Walker   655  204  167   64   42        3
